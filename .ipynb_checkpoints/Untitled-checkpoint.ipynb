# %%
import sys
# !{sys.executable} -m pip install langchain_aws

# %%
from langchain.vectorstores import FAISS
from langchain.chains import RetrievalQA
from langchain.embeddings import BedrockEmbeddings
from langchain_community.document_loaders import PyPDFLoader
from src.model.bedrock import Bedrock
from src.utils import helper

# %%
tempdir='.'
loader = PyPDFLoader('/Users/sharmin/Downloads/SF Workflow.pdf')
docs = loader.load()
bedrock_obj = Bedrock()
split_docs = helper.chunk_split(docs=docs)
vectorstore_faiss = FAISS.from_documents(documents=split_docs, embedding=bedrock_obj.embeddings_llm)
vectorstore_faiss.save_local(folder_path=tempdir)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 5
#       3 docs = loader.load()
#       4 bedrock_obj = Bedrock()
# ----> 5 split_docs = helper.chunk_split(docs=docs)
#       6 vectorstore_faiss = FAISS.from_documents(documents=split_docs, embedding=bedrock_obj.embeddings_llm)
#       7 vectorstore_faiss.save_local(folder_path=tempdir)
#
# NameError: name 'helper' is not defined
