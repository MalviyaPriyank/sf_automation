# %%
'["a","b"]'.tolist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 '["a","b"]'.tolist()
#
# AttributeError: 'str' object has no attribute 'tolist'
